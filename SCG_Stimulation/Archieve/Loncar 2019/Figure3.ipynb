# %%
import laserfun as lf
import matplotlib.pyplot as plt
import scipy
import numpy as np
import pandas as pd
from scipy.interpolate import UnivariateSpline
from scipy.constants import speed_of_light as c

# pulse parameters
FWHM = 160 * 1e-3# pulse duration (ps)
pulseWL = 1506  # pulse central wavelength (nm)
length = 5 * 1e-3

epp =187e-12  # W
GDD = False  # Group delay dispersion (ps^2)
TOD = False  # Third order dispersion (ps^3)
FOD = False  # Fourth order dispersion


# simulation parameters
Window = 10  # simulation window (ps)
Steps = 100  # simulation steps
Points = 2 ** 14  # simulation points
rtol = 1e-4  # relative error for NLSE integrator
atol = 1e-4  # absolute error
Raman = True  # Enable Raman effect?
Steep = True  # Enable self steepening?

# ----------- Build Waveguide -----------
n2 = 1e-19  # m^2/W n2 is the nonlinear refractive index at the center
Alpha = 0  # loss (dB/cm)

data = np.load(f"data_h_{0.35}_w_{0.8}_ne.npz")
wls = data['wls']
neff_list = data['neff_list_te']
aeff_list = data['aeff_list_te']


def disp_function(z=0):  # provide effective index to the NLSE
    return (wls, neff_list)


# Calculate Gamma
def gamma_function(wl):  # provide the nonlinearity at the pump to the NLSE
    aeff_interp = scipy.interpolate.interp1d(wls, aeff_list)
    gamma = 2 * np.pi * n2 / (wl * 1e-9 * aeff_interp(wl) * 1e-12)
    return gamma


gamma = gamma_function(pulseWL)
print(gamma)
# create the pulse:
p = lf.Pulse(pulse_type='gaussian', fwhm_ps=FWHM, center_wavelength_nm=pulseWL,
             time_window_ps=Window, GDD=GDD, TOD=TOD, FOD=FOD,
             npts=Points, epp=epp, power_is_avg=False, frep_MHz=100)
p.add_noise()
# create the waveguide
f = lf.Fiber(length, center_wl_nm=pulseWL, dispersion_format='GVD',
             gamma_W_m=gamma, loss_dB_per_m=Alpha * 100)

f.set_dispersion_function(disp_function, dispersion_format='n')

# propagate the pulse using the NLSE
results = lf.NLSE(p, f, raman=Raman, shock=Steep, nsaves=Steps, rtol=rtol,
                  atol=atol, print_status=True)

fig, axes = results.plot(wavelength=True, show=False, tlim=(-5, 5), flim=(0, 3000), units="dB", cparam=[50, 60])

plt.set_cmap('jet')
plt.show()
# Out:
# 0.5066311662785158
#    1.0% - 5.051e-05 m - 0.0 seconds
#    2.0% - 1.010e-04 m - 0.0 seconds
#    3.0% - 1.515e-04 m - 0.0 seconds
#    4.0% - 2.020e-04 m - 0.0 seconds
#    5.1% - 2.525e-04 m - 0.0 seconds
#    6.1% - 3.030e-04 m - 0.0 seconds
#    7.1% - 3.535e-04 m - 0.0 seconds
#    8.1% - 4.040e-04 m - 0.0 seconds
#    9.1% - 4.545e-04 m - 0.0 seconds
#   10.1% - 5.051e-04 m - 0.0 seconds
#   11.1% - 5.556e-04 m - 0.0 seconds
#   12.1% - 6.061e-04 m - 0.0 seconds
#   13.1% - 6.566e-04 m - 0.0 seconds
#   14.1% - 7.071e-04 m - 0.0 seconds
#   15.2% - 7.576e-04 m - 0.0 seconds
#   16.2% - 8.081e-04 m - 0.0 seconds
#   17.2% - 8.586e-04 m - 0.0 seconds
#   18.2% - 9.091e-04 m - 0.0 seconds
#   19.2% - 9.596e-04 m - 0.0 seconds
#   20.2% - 1.010e-03 m - 0.0 seconds
#   21.2% - 1.061e-03 m - 0.0 seconds
#   22.2% - 1.111e-03 m - 0.0 seconds
#   23.2% - 1.162e-03 m - 0.0 seconds
#   24.2% - 1.212e-03 m - 0.0 seconds
#   25.3% - 1.263e-03 m - 0.0 seconds
#   26.3% - 1.313e-03 m - 0.0 seconds
#   27.3% - 1.364e-03 m - 0.0 seconds
#   28.3% - 1.414e-03 m - 0.0 seconds
#   29.3% - 1.465e-03 m - 0.0 seconds
#   30.3% - 1.515e-03 m - 0.0 seconds
#   31.3% - 1.566e-03 m - 0.0 seconds
#   32.3% - 1.616e-03 m - 0.0 seconds
#   33.3% - 1.667e-03 m - 0.0 seconds
#   34.3% - 1.717e-03 m - 0.0 seconds
#   35.4% - 1.768e-03 m - 0.0 seconds
#   36.4% - 1.818e-03 m - 0.0 seconds
#   37.4% - 1.869e-03 m - 0.0 seconds
#   38.4% - 1.919e-03 m - 0.0 seconds
#   39.4% - 1.970e-03 m - 0.0 seconds
#   40.4% - 2.020e-03 m - 0.1 seconds
#   41.4% - 2.071e-03 m - 0.1 seconds
#   42.4% - 2.121e-03 m - 0.1 seconds
#   43.4% - 2.172e-03 m - 0.1 seconds
#   44.4% - 2.222e-03 m - 0.1 seconds
#   45.5% - 2.273e-03 m - 0.1 seconds
#   46.5% - 2.323e-03 m - 0.1 seconds
#   47.5% - 2.374e-03 m - 0.1 seconds
#   48.5% - 2.424e-03 m - 0.1 seconds
#   49.5% - 2.475e-03 m - 0.1 seconds
#   50.5% - 2.525e-03 m - 0.1 seconds
#   51.5% - 2.576e-03 m - 0.1 seconds
#   52.5% - 2.626e-03 m - 0.1 seconds
#   53.5% - 2.677e-03 m - 0.1 seconds
#   54.5% - 2.727e-03 m - 0.1 seconds
#   55.6% - 2.778e-03 m - 0.1 seconds
#   56.6% - 2.828e-03 m - 0.1 seconds
#   57.6% - 2.879e-03 m - 0.1 seconds
#   58.6% - 2.929e-03 m - 0.1 seconds
#   59.6% - 2.980e-03 m - 0.1 seconds
#   60.6% - 3.030e-03 m - 0.1 seconds
#   61.6% - 3.081e-03 m - 0.1 seconds
#   62.6% - 3.131e-03 m - 0.1 seconds
#   63.6% - 3.182e-03 m - 0.1 seconds
#   64.6% - 3.232e-03 m - 0.1 seconds
#   65.7% - 3.283e-03 m - 0.1 seconds
#   66.7% - 3.333e-03 m - 0.1 seconds
#   67.7% - 3.384e-03 m - 0.1 seconds
#   68.7% - 3.434e-03 m - 0.1 seconds
#   69.7% - 3.485e-03 m - 0.1 seconds
#   70.7% - 3.535e-03 m - 0.1 seconds
#   71.7% - 3.586e-03 m - 0.1 seconds
#   72.7% - 3.636e-03 m - 0.1 seconds
#   73.7% - 3.687e-03 m - 0.1 seconds
#   74.7% - 3.737e-03 m - 0.1 seconds
#   75.8% - 3.788e-03 m - 0.1 seconds
#   76.8% - 3.838e-03 m - 0.1 seconds
#   77.8% - 3.889e-03 m - 0.1 seconds
#   78.8% - 3.939e-03 m - 0.1 seconds
#   79.8% - 3.990e-03 m - 0.1 seconds
#   80.8% - 4.040e-03 m - 0.2 seconds
#   81.8% - 4.091e-03 m - 0.2 seconds
#   82.8% - 4.141e-03 m - 0.2 seconds
#   83.8% - 4.192e-03 m - 0.2 seconds
#   84.8% - 4.242e-03 m - 0.2 seconds
#   85.9% - 4.293e-03 m - 0.2 seconds
#   86.9% - 4.343e-03 m - 0.2 seconds
#   87.9% - 4.394e-03 m - 0.3 seconds
#   88.9% - 4.444e-03 m - 0.3 seconds
#   89.9% - 4.495e-03 m - 0.3 seconds
#   90.9% - 4.545e-03 m - 0.3 seconds
#   91.9% - 4.596e-03 m - 0.3 seconds
#   92.9% - 4.646e-03 m - 0.3 seconds
#   93.9% - 4.697e-03 m - 0.4 seconds
#   94.9% - 4.747e-03 m - 0.4 seconds
#   96.0% - 4.798e-03 m - 0.4 seconds
#   97.0% - 4.848e-03 m - 0.4 seconds
#   98.0% - 4.899e-03 m - 0.5 seconds
#   99.0% - 4.949e-03 m - 0.5 seconds
#  100.0% - 5.000e-03 m - 0.5 seconds

# %%
import scipy
import matplotlib.pyplot as plt
import numpy as np
from scipy.constants import pi, c
from matplotlib import pyplot as plt

import pynlo
from pynlo import utility as ut

# pulse parameters
n_points = 2 ** 14
center_wl = 1555 * 1e-9
start_wl = 600 * 1e-9
end_wl = 2200 * 1e-9

e_p = 1400e-12  # energy per pulse in joules
t_fwhm = 125e-15  # for sech, fwhm = 1.76 * pulse duration 

f_min = c / (end_wl)  # c / l
f_max = c / (start_wl)  # c / l
f0 = c / center_wl  # c / 

pulse = pynlo.light.Pulse.Gaussian(n_points, f_min, f_max, f0, e_p, t_fwhm,
                               alias=2)  # alias = number of harmonic support by the real-valued time domain grid

wls = data['wls'] * 1e-9
aeff_list = data['aeff_list_tm']
neff_list = data['neff_list_tm']

aeff_interp = scipy.interpolate.interp1d(wls, aeff_list)
neff_interp = scipy.interpolate.interp1d(wls, neff_list)

length = 5e-3  # 10 mm
a_eff = aeff_interp(center_wl) * 1e-12

#---- Phase Coefficient
w_grid = c / pulse.v_grid
n_eff = neff_interp(w_grid)
beta = n_eff * 2 * pi * pulse.v_grid / c

#---- 2nd-order nonlinearity
chi2_eff = 30e-12 * 2  # pm / V
g2 = ut.chi2.g2_shg(f0, pulse.v_grid, n_eff, a_eff, chi2_eff)

# 3rd-Order Nonlinearity
n2 = 1e-19


def gamma_function(pump_wl):  # provide the nonlinearity at the pump to the NLSE
    aeff_interp = scipy.interpolate.interp1d(wls, aeff_list)
    gamma = 2 * np.pi * n2 / (pump_wl * aeff_interp(pump_wl) * 1e-12)
    return gamma


gamma = gamma_function(w_grid)  #1/(W*m)
print(gamma)
g3 = ut.chi3.gamma_to_g3(pulse.v_grid, gamma)

mode = pynlo.medium.Mode(pulse.v_grid, beta, g3=g3, g2=g2)

#----build model
model = pynlo.model.UPE(pulse, mode)

#---- Estimate step size
local_error = 1e-6
dz = model.estimate_step_size(local_error=local_error)

pulse_out, z, a_t, a_v = model.simulate(length, dz=dz, local_error=local_error, n_records=100, plot="wvl")

fig = plt.figure(figsize=(8, 8))
ax0 = plt.subplot2grid((3, 2), (0, 0), rowspan=1)
ax1 = plt.subplot2grid((3, 2), (0, 1), rowspan=1)
ax2 = plt.subplot2grid((3, 2), (1, 0), rowspan=2, sharex=ax0)
ax3 = plt.subplot2grid((3, 2), (1, 1), rowspan=2, sharex=ax1)

p_v_dB = 10 * np.log10(np.abs(a_v) ** 2)
p_v_dB -= p_v_dB.max()

w_grid = c / (pulse.v_grid) * 1e9
ax0.plot(w_grid, p_v_dB[0], color="b", label='Initial')
ax0.plot(w_grid, p_v_dB[-1], color="r", label="pynlo")
ax2.pcolormesh(w_grid, 1e3 * z, p_v_dB,
               vmin=-40.0, vmax=0, shading="auto", cmap="jet")
ax0.set_ylim(bottom=-60, top=10)
ax2.set_xlabel('wavelegnth (nm)')

p_t_dB = 10 * np.log10(np.abs(a_t) ** 2)
p_t_dB -= p_t_dB.max()
ax1.plot(1e12 * pulse.t_grid, p_t_dB[0], color="b", label='Initial')
ax1.plot(1e12 * pulse.t_grid, p_t_dB[-1], color="r")
ax3.pcolormesh(1e12 * pulse.t_grid, 1e3 * z, p_t_dB,
               vmin=-40.0, vmax=0, shading="auto")

ax1.set_ylim(bottom=-80, top=10)
ax1.set_xlim(-4, 4)
ax3.set_xlabel('Time (ps)')

ax0.set_ylabel('Power (dB)')
ax2.set_ylabel('Propagation Distance (mm)')
#------------- Plot reference -----------

ref = pd.read_csv(
    "../reference_data/Figure2b.csv", dtype=np.float64
)
ref_x, ref_y = np.split(ref.values, 2, axis=1)

ax0.plot(ref_x, ref_y - 50, c="green", label="paper(experiement)", zorder=0)
ax0.legend(loc="upper right", prop={'size': 6}, fontsize=8)

fig.tight_layout()
fig.show()
# Out:
# [0.1777338  0.17784151 0.17794928 ... 2.11413434 2.11424602 2.1143577 ]
# C:\Users\a1890865\AppData\Local\anaconda3\envs\SC-generation-stimulation\lib\site-packages\pynlo\model.py:617: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   self._rt_fig.show()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 68
#      65 local_error = 1e-6
#      66 dz = model.estimate_step_size(local_error=local_error)
# ---> 68 pulse_out, z, a_t, a_v = model.simulate(length, dz=dz, local_error=local_error, n_records=100, plot="wvl")
#      70 fig = plt.figure(figsize=(8, 8))
#      71 ax0 = plt.subplot2grid((3, 2), (0, 0), rowspan=1)
#
# File ~\AppData\Local\anaconda3\envs\SC-generation-stimulation\lib\site-packages\pynlo\model.py:284, in Model.simulate(self, z_grid, dz, local_error, n_records, plot)
#     281 cont = False
#     282 for z_stop in z_grid[1:]:
#     283     # Step
# --> 284     (pulse_out.a_v, z, dz, k5_v, cont) = self.propagate(
#     285         pulse_out.a_v,
#     286         z, z_stop, dz,
#     287         local_error,
#     288         k5_v=k5_v,
#     289         cont=cont)
#     291     # Record
#     292     if z in z_record:
#
# File ~\AppData\Local\anaconda3\envs\SC-generation-stimulation\lib\site-packages\pynlo\model.py:1008, in UPE.propagate(self, a_v, z, z_stop, dz, local_error, k5_v, cont)
#    1005         k5_v = None # reset k5_v, 2nd-order nonlinearity changed sign
#    1007 #---- Propagate
# -> 1008 return super().propagate(a_v, z, z_stop, dz, local_error, k5_v=k5_v, cont=cont)
#
# File ~\AppData\Local\anaconda3\envs\SC-generation-stimulation\lib\site-packages\pynlo\model.py:372, in Model.propagate(self, a_v, z, z_stop, dz, local_error, k5_v, cont)
#     369     final_step = False
#     371 #---- Integrate by dz
# --> 372 a_RK4_v, a_RK3_v, k5_v_next = self.step(a_v, z, z_next, k5_v=k5_v, cont=cont)
#     374 #---- Estimate Relative Local Error
#     375 est_error = l2_error(a_RK4_v, a_RK3_v)
#
# File ~\AppData\Local\anaconda3\envs\SC-generation-stimulation\lib\site-packages\pynlo\model.py:482, in Model.step(self, a_v, z, z_next, k5_v, cont)
#     479 a_RK4_v, b_v = rk4(ai_v, ki1_v, ki2_v, ki3_v, k4_v, ip_v, dz)
#     481 #---- k5
# --> 482 k5_v = self._nonlinear_operator(a_RK4_v)
#     484 #---- RK3
#     485 a_RK3_v = rk3(b_v, k4_v, k5_v, dz)
#
# File ~\AppData\Local\anaconda3\envs\SC-generation-stimulation\lib\site-packages\pynlo\model.py:1030, in UPE.nonlinear_operator(self, a_v)
#    1028 #---- Setup
#    1029 self._nl_v[...] = self._0_v # zero
# -> 1030 self._a_rv[self.rn_slice] = a_v
#    1031 a_rt = fft.irfft(self._a_rv, fsc=self.rdt * 2**0.5, n=self.rn_points) # 1/2**0.5 for analytic to real
#    1032 a2_rt = a_rt * a_rt
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.constants import c

import pychi

eps_0 = 8.8541878128e-12

### Simulation
t_pts = 2 ** 14

### Light
pulse_duration = 125 * 1e-15
pulse_wavelength = 1.555e-06
pulse_energy = 1400e-12

###Load data
data = np.load(f"data_h_0.2_w_1.3_no.npz")
wg_freq = c / (data['wls'] * 1e-9)
wg_neff = data['neff_list_tm']
aeff_list = data['aeff_list_tm'] * 1e-12

aeff_interp = scipy.interpolate.interp1d(data['wls'] * 1e-9, aeff_list)
neff_interp = scipy.interpolate.interp1d(wg_freq, wg_neff)
wg_aeff = aeff_interp(pulse_wavelength)

### Waveguide
wg_length = 5 * 1e-3
wg_chi_2 = 30e-12
n2 = 1e-19


def wg_chi_3(z, freq):
    return 4 / 3 * neff_interp(freq) ** 2 * c * n2 * eps_0


print(wg_chi_3(0, c / pulse_wavelength))

### Prepare waveguide
waveguide = pychi.materials.Waveguide(wg_freq, wg_neff, wg_chi_2, wg_chi_3,
                                      wg_aeff, wg_length, t_pts=t_pts)
waveguide.plot_refractive_index()
### Prepare input pulse
pulse = pychi.light.Gaussian(waveguide, pulse_duration, pulse_energy, pulse_wavelength)

### Prepare model
model = pychi.models.SpmChi2Chi3(waveguide, pulse)

### Prepare solver, solve
solver = pychi.solvers.Solver(model, z_pts=100)
solver.solve()

### Plot
plt.figure()
plt.plot(pulse.wl * 1e9, 20 * np.log10(pulse.spectrum_wl[-1] / np.amax(pulse.spectrum_wl[-1])) - 3)
plt.xlim(500, 2000)
plt.ylim(-75, 5)
plt.title('SpmChi2Chi3')
plt.xlabel('Wavelength [m]')
plt.ylabel('Intensity [dB]')

#------------- Plot reference -----------

ref = pd.read_csv(
    "../reference_data/Figure2b.csv", dtype=np.float64
)
ref_x, ref_y = np.split(ref.values, 2, axis=1)

plt.plot(ref_x, ref_y - 50, c="green", label="paper(experiement)", zorder=0)
plt.legend(loc="upper right", prop={'size': 6}, fontsize=8)
fig.tight_layout()
fig.show()

#------------- Plot reference -----------
pulse.plot_propagation("pychi")
# Results can also be accessed via pulse.z_save, pulse.freq, pulse.spectrum, pulse.waveform
# The refractive index and GVD can be seen with waveguide.plot_refractive_index()
# Out:
# 1.139594263731168e-21
# z: 1/100
# z: 2/100
# Discarded
# Discarded
# z: 3/100
# z: 4/100
# z: 5/100
# z: 6/100
# z: 7/100
# z: 8/100
# z: 9/100
# z: 10/100
# z: 11/100
# z: 12/100
# z: 13/100
# z: 14/100
# z: 15/100
# z: 16/100
# z: 17/100
# z: 18/100
# z: 19/100
# z: 20/100
# z: 21/100
# z: 22/100
# z: 23/100
# z: 24/100
# z: 25/100
# z: 26/100
# z: 27/100
# z: 28/100
# z: 29/100
# z: 30/100
# z: 31/100
# z: 32/100
# Discarded
# Discarded
# z: 33/100
# z: 34/100
# z: 35/100
# z: 36/100
# z: 37/100
# z: 38/100
# z: 39/100
# z: 40/100
# z: 41/100
# z: 42/100
# z: 43/100
# z: 44/100
# z: 45/100
# z: 46/100
# z: 47/100
# z: 48/100
# z: 49/100
# z: 50/100
# z: 51/100
# z: 52/100
# z: 53/100
# z: 54/100
# z: 55/100
# z: 56/100
# z: 57/100
# z: 58/100
# z: 59/100
# z: 60/100
# z: 61/100
# z: 62/100
# z: 63/100
# z: 64/100
# z: 65/100
# z: 66/100
# z: 67/100
# z: 68/100
# z: 69/100
# z: 70/100
# z: 71/100
# z: 72/100
# z: 73/100
# z: 74/100
# z: 75/100
# z: 76/100
# z: 77/100
# z: 78/100
# z: 79/100
# z: 80/100
# z: 81/100
# z: 82/100
# z: 83/100
# z: 84/100
# z: 85/100
# z: 86/100
# z: 87/100
# z: 88/100
# z: 89/100
# z: 90/100
# z: 91/100
# z: 92/100
# z: 93/100
# z: 94/100
# Discarded
# Discarded
# Discarded
# Discarded
# z: 95/100
# Discarded
# Discarded
# z: 96/100
# z: 97/100
# z: 98/100
# z: 99/100
# z: 100/100
# 175.87870429997565 seconds for integration.
# C:\Users\eliza\AppData\Local\Temp\ipykernel_28568\2462732461.py:72: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.constants import c

import pychi

eps_0 = 8.8541878128e-12

### Simulation
t_pts = 2 ** 14

### Light
pulse_duration = 125 * 1e-15
pulse_wavelength = 1.555e-06
pulse_energy = 1400e-12

###Load data

data = np.load(f"data_h_0.2_w_1.3_no.npz")
wg_freq = c / (data['wls'] * 1e-9)
wg_neff = data['neff_list_tm']
aeff_list = data['aeff_list_tm'] * 1e-12

aeff_interp = scipy.interpolate.interp1d(data['wls'] * 1e-9, aeff_list)
neff_interp = scipy.interpolate.interp1d(wg_freq, wg_neff)
wg_aeff = aeff_interp(pulse_wavelength)

### Waveguide
wg_length = 5 * 1e-3
wg_chi_2 =54e-12
n2 = 1e-19


def wg_chi_3(z, freq):
    return 4 / 3 * neff_interp(freq) ** 2 * c * n2 * eps_0


print(wg_chi_3(0, c / pulse_wavelength))

### Prepare waveguide
waveguide = pychi.materials.Waveguide(wg_freq, wg_neff, wg_chi_2, wg_chi_3,
                                      wg_aeff, wg_length, t_pts=t_pts)
waveguide.plot_refractive_index()
### Prepare input pulse
pulse = pychi.light.Sech(waveguide, pulse_duration, pulse_energy, pulse_wavelength)

### Prepare model
model = pychi.models.SpmChi3(waveguide, pulse)

### Prepare solver, solve
solver = pychi.solvers.Solver(model, z_pts=100)
solver.solve()

###Plot
plt.figure()
plt.plot(pulse.wl * 1e9, 20 * np.log10(pulse.spectrum_wl[-1] / np.amax(pulse.spectrum_wl[-1])) - 3)
plt.xlim(500, 2000)
plt.ylim(-75, 5)
plt.title('SpmChi2Chi3')
plt.xlabel('Wavelength [m]')
plt.ylabel('Intensity [dB]')

#------------- Plot reference -----------

ref = pd.read_csv(
    "../reference_data/Figure2b.csv", dtype=np.float64
)
ref_x, ref_y = np.split(ref.values, 2, axis=1)

plt.plot(ref_x, ref_y - 50, c="green", label="paper(experiement)", zorder=0)
plt.legend(loc="upper right", prop={'size': 6}, fontsize=8)
fig.tight_layout()
fig.show()

pulse.plot_propagation("pychi")
# Results can also be accessed via pulse.z_save, pulse.freq, pulse.spectrum, pulse.waveform
# The refractive index and GVD can be seen with waveguide.plot_refractive_index()
# Out:
# 1.139594263731168e-21
# z: 1/100
# z: 2/100
# Discarded
# Discarded
# z: 3/100
# z: 4/100
# z: 5/100
# z: 6/100
# z: 7/100
# z: 8/100
# z: 9/100
# z: 10/100
# z: 11/100
# z: 12/100
# z: 13/100
# z: 14/100
# z: 15/100
# z: 16/100
# z: 17/100
# z: 18/100
# z: 19/100
# z: 20/100
# z: 21/100
# z: 22/100
# z: 23/100
# z: 24/100
# z: 25/100
# z: 26/100
# z: 27/100
# z: 28/100
# z: 29/100
# z: 30/100
# z: 31/100
# z: 32/100
# z: 33/100
# z: 34/100
# z: 35/100
# z: 36/100
# z: 37/100
# z: 38/100
# z: 39/100
# z: 40/100
# z: 41/100
# z: 42/100
# z: 43/100
# z: 44/100
# z: 45/100
# z: 46/100
# z: 47/100
# z: 48/100
# z: 49/100
# z: 50/100
# z: 51/100
# z: 52/100
# z: 53/100
# z: 54/100
# z: 55/100
# z: 56/100
# z: 57/100
# z: 58/100
# z: 59/100
# z: 60/100
# z: 61/100
# z: 62/100
# z: 63/100
# z: 64/100
# z: 65/100
# z: 66/100
# z: 67/100
# z: 68/100
# z: 69/100
# z: 70/100
# z: 71/100
# z: 72/100
# z: 73/100
# z: 74/100
# z: 75/100
# z: 76/100
# z: 77/100
# z: 78/100
# z: 79/100
# z: 80/100
# z: 81/100
# z: 82/100
# z: 83/100
# z: 84/100
# z: 85/100
# z: 86/100
# z: 87/100
# z: 88/100
# z: 89/100
# z: 90/100
# z: 91/100
# z: 92/100
# z: 93/100
# z: 94/100
# z: 95/100
# z: 96/100
# z: 97/100
# z: 98/100
# z: 99/100
# z: 100/100
# 131.17887830000836 seconds for integration.
# C:\Users\eliza\AppData\Local\Temp\ipykernel_28568\1830271063.py:73: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
