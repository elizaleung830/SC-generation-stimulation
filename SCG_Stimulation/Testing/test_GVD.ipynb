# %% [markdown]
# Condition:
# - Gaussian pulse shape (m =1)
# - $\gamma = 0 W^{-1}m^{-1}$
# - $P_0 = 5W$
# - $T_0 = 0.2ps$
# - $L = 1m $
# -$L_d = \frac{T_0^2}{\beta_2} = 1m$ for $\beta_2 = 0.04$

# %%
import laserfun as lf
# Build Pulse
pulse1 = lf.Pulse(pulse_type='gaussian', center_wavelength_nm=1550, 
                 fwhm_ps=0.2, time_window_ps=10, power=5)

# Build Fibre
fiber1 = lf.Fiber(length=1, center_wl_nm=1550, dispersion_format='GVD',
                 dispersion=[0.04,0,0], gamma_W_m=0, loss_dB_per_m=0)

# Get Result
results1 = lf.NLSE(pulse1, fiber1 , print_status=False, raman=False)
# Plot Result
results1.plot()
# Out:
# (<Figure size 800x800 with 4 Axes>,
#  array([[<Axes: xlabel='Frequency (THz)', ylabel='Intensity (dBm)'>,
#          <Axes: xlabel='Time (ps)'>],
#         [<Axes: xlabel='Frequency (THz)', ylabel='Spectral Flux (dbm/nm)'>,
#          <Axes: xlabel='Time (ps)'>]], dtype=object))

# %% [markdown]
# Now flip the sign of $\beta_2$, shouldn't change the boardening of shape (since input pulse is unchriped)

# %%
import laserfun as lf
# Build Pulse
pulse1 = lf.Pulse(pulse_type='gaussian', center_wavelength_nm=1550, 
                 fwhm_ps=0.2, time_window_ps=10, power=5)

# Build Fibre
fiber1 = lf.Fiber(length=1, center_wl_nm=1550, dispersion_format='GVD',
                 dispersion=[-0.04,0,0], gamma_W_m=0, loss_dB_per_m=0)

# Get Result
results1 = lf.NLSE(pulse1, fiber1 , print_status=False, raman=False)
# Plot Result
results1.plot()
# Out:
# (<Figure size 800x800 with 4 Axes>,
#  array([[<Axes: xlabel='Frequency (THz)', ylabel='Intensity (dBm)'>,
#          <Axes: xlabel='Time (ps)'>],
#         [<Axes: xlabel='Frequency (THz)', ylabel='Spectral Flux (dbm/nm)'>,
#          <Axes: xlabel='Time (ps)'>]], dtype=object))

# %% [markdown]
# Decrease the length, should be broadening less now

# %%
import laserfun as lf
# Build Pulse
pulse1 = lf.Pulse(pulse_type='gaussian', center_wavelength_nm=1550, 
                 fwhm_ps=0.2, time_window_ps=10, power=5)

# Build Fibre
fiber1 = lf.Fiber(length=0.5, center_wl_nm=1550, dispersion_format='GVD',
                 dispersion=[-0.04,0,0], gamma_W_m=0, loss_dB_per_m=0)

# Get Result
results1 = lf.NLSE(pulse1, fiber1 , print_status=False, raman=False)
# Plot Result
results1.plot()
# Out:
# (<Figure size 800x800 with 4 Axes>,
#  array([[<Axes: xlabel='Frequency (THz)', ylabel='Intensity (dBm)'>,
#          <Axes: xlabel='Time (ps)'>],
#         [<Axes: xlabel='Frequency (THz)', ylabel='Spectral Flux (dbm/nm)'>,
#          <Axes: xlabel='Time (ps)'>]], dtype=object))
