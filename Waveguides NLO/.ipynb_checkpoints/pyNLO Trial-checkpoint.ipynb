# %%
# importing built-in libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# importing non-linear optics library
import pynlo
from pynlo.interactions.FourWaveMixing import SSFM
from pynlo.media.fibers import fiber
from pynlo.light.DerivedPulses import SechPulse

# %% [markdown]
# 50 fs pulse through nonlinear fiber using split-step Fourier model

# %%
# setting up parameters

FWHM    = 0.050  # pulse duration (ps)
pulseWL = 1550   # pulse central wavelength (nm)
EPP     = 50e-12 # Energy per pulse (J)
GDD     = 0.0    # Group delay dispersion (ps^2)
TOD     = 0.0    # Third order dispersion (ps^3)

Window  = 10.0   # simulation window (ps)
Steps   = 100    # simulation steps
Points  = 2**13  # simulation points

beta2   = -120     # (ps^2/km)
beta3   = 0.00     # (ps^3/km)
beta4   = 0.005    # (ps^4/km)

Length  = 20    # length in mm

Alpha   = 0.0     # attentuation coefficient (dB/cm)
Gamma   = 1000    # Gamma (1/(W km)

fibWL   = pulseWL # Center WL of fiber (nm)

Raman   = True    # Enable Raman effect?
Steep   = True    # Enable self steepening?

alpha = np.log((10**(Alpha * 0.1))) * 100  # convert from dB/cm to 1/m

# %%
# set up plots for the results:

fig = plt.figure(figsize=(8,8))
ax0 = plt.subplot2grid((3,2), (0, 0), rowspan=1)
ax1 = plt.subplot2grid((3,2), (0, 1), rowspan=1)
ax2 = plt.subplot2grid((3,2), (1, 0), rowspan=2, sharex=ax0)
ax3 = plt.subplot2grid((3,2), (1, 1), rowspan=2, sharex=ax1)


######## This is where the PyNLO magic happens! ############################

# create the pulse!
pulse = pynlo.light.DerivedPulses.SechPulse(power = 1, # Power will be scaled by set_epp
                                            T0_ps                   = FWHM/1.76,
                                            center_wavelength_nm    = pulseWL,
                                            time_window_ps          = Window,
                                            GDD=GDD, TOD=TOD,
                                            NPTS            = Points,
                                            frep_MHz        = 100,
                                            power_is_avg    = False)
# set the pulse energy!
pulse.set_epp(EPP)

# create the fiber!
fiber1 = pynlo.media.fibers.fiber.FiberInstance()
fiber1.generate_fiber(Length * 1e-3, center_wl_nm=fibWL, betas=(beta2, beta3, beta4),
                              gamma_W_m=Gamma * 1e-3, gvd_units='ps^n/km', gain=-alpha)

# Propagation
evol = pynlo.interactions.FourWaveMixing.SSFM.SSFM(local_error=0.005, USE_SIMPLE_RAMAN=True,
                 disable_Raman              = np.logical_not(Raman),
                 disable_self_steepening    = np.logical_not(Steep))

y, AW, AT, pulse_out = evol.propagate(pulse_in=pulse, fiber=fiber1, n_steps=Steps)

########## That's it! Physics complete. Just plotting commands from here! ################


F = pulse.F_THz     # Frequency grid of pulse (THz)

def dB(num):
    return 10 * np.log10(np.abs(num)**2)

zW = dB( np.transpose(AW)[:, (F > 0)] )
zT = dB( np.transpose(AT) )

y_mm = y * 1e3 # convert distance to mm

ax0.plot(pulse_out.F_THz,    dB(pulse_out.AW),  color = 'r')
ax1.plot(pulse_out.T_ps,     dB(pulse_out.AT),  color = 'r')

ax0.plot(pulse.F_THz,    dB(pulse.AW),  color = 'b')
ax1.plot(pulse.T_ps,     dB(pulse.AT),  color = 'b')

extent = (np.min(F[F > 0]), np.max(F[F > 0]), 0, Length)
ax2.imshow(zW, extent=extent,
           vmin=np.max(zW) - 40.0, vmax=np.max(zW),
           aspect='auto', origin='lower')

extent = (np.min(pulse.T_ps), np.max(pulse.T_ps), np.min(y_mm), Length)
ax3.imshow(zT, extent=extent,
           vmin=np.max(zT) - 40.0, vmax=np.max(zT),
           aspect='auto', origin='lower')


ax0.set_ylabel('Intensity (dB)')
ax0.set_ylim( - 80,  0)
ax1.set_ylim( - 40, 40)

ax2.set_ylabel('Propagation distance (mm)')
ax2.set_xlabel('Frequency (THz)')
ax2.set_xlim(0,400)

ax3.set_xlabel('Time (ps)')

plt.show()
# Out:
# Pulse energy before Simple Fiber : 0.05000000000000002 nJ
# pulse energy in  2168.8948070049555
# copied as   2168.8948070049555
# Step: 0 Distance remaining: 0.02
# Pulse energy after: 0.04891448568583004 nJ
# Step: 1 Distance remaining: 0.0198
# Pulse energy after: 0.04889521530938357 nJ
# Step: 2 Distance remaining: 0.0196
# Pulse energy after: 0.048868880301759024 nJ
# Step: 3 Distance remaining: 0.0194
# Pulse energy after: 0.048835315815702614 nJ
# Step: 4 Distance remaining: 0.0192
# Pulse energy after: 0.04879434799129516 nJ
# Step: 5 Distance remaining: 0.019
# Pulse energy after: 0.04874590507130721 nJ
# Step: 6 Distance remaining: 0.0188
# Pulse energy after: 0.048690184686442005 nJ
# Step: 7 Distance remaining: 0.0186
# Pulse energy after: 0.048627904377267536 nJ
# Step: 8 Distance remaining: 0.0184
# Pulse energy after: 0.048560665497211 nJ
# Step: 9 Distance remaining: 0.0182
# Pulse energy after: 0.048491452226983166 nJ
# Step: 10 Distance remaining: 0.018000000000000002
# Pulse energy after: 0.048425256401294296 nJ
# Step: 11 Distance remaining: 0.0178
# Pulse energy after: 0.04836971944818368 nJ
# Step: 12 Distance remaining: 0.0176
# Pulse energy after: 0.048335505303909794 nJ
# Step: 13 Distance remaining: 0.0174
# Pulse energy after: 0.04833581659223897 nJ
# Step: 14 Distance remaining: 0.0172
# Pulse energy after: 0.04838412554122076 nJ
# Step: 15 Distance remaining: 0.017
# Pulse energy after: 0.04848913394688858 nJ
# Step: 16 Distance remaining: 0.0168
# Pulse energy after: 0.048646979578571975 nJ
# Step: 17 Distance remaining: 0.0166
# Pulse energy after: 0.048832255485894926 nJ
# Step: 18 Distance remaining: 0.0164
# Pulse energy after: 0.048997843478160746 nJ
# Step: 19 Distance remaining: 0.016200000000000003
# Pulse energy after: 0.049093738149755727 nJ
# Step: 20 Distance remaining: 0.016
# Pulse energy after: 0.049091133663803285 nJ
# Step: 21 Distance remaining: 0.0158
# Pulse energy after: 0.04900269967231569 nJ
# Step: 22 Distance remaining: 0.015600000000000001
# Pulse energy after: 0.04887236721899797 nJ
# Step: 23 Distance remaining: 0.0154
# Pulse energy after: 0.04874711641666635 nJ
# Step: 24 Distance remaining: 0.0152
# Pulse energy after: 0.04865471994119501 nJ
# Step: 25 Distance remaining: 0.015
# Pulse energy after: 0.04859860142514132 nJ
# Step: 26 Distance remaining: 0.0148
# Pulse energy after: 0.04856545279937319 nJ
# Step: 27 Distance remaining: 0.0146
# Pulse energy after: 0.0485362997023887 nJ
# Step: 28 Distance remaining: 0.0144
# Pulse energy after: 0.04849538566347441 nJ
# Step: 29 Distance remaining: 0.014199999999999999
# Pulse energy after: 0.048435131268020126 nJ
# Step: 30 Distance remaining: 0.013999999999999999
# Pulse energy after: 0.048358315145276165 nJ
# Step: 31 Distance remaining: 0.0138
# Pulse energy after: 0.04827695774911484 nJ
# Step: 32 Distance remaining: 0.0136
# Pulse energy after: 0.04820882701980533 nJ
# Step: 33 Distance remaining: 0.013399999999999999
# Pulse energy after: 0.048169350095893786 nJ
# Step: 34 Distance remaining: 0.013199999999999998
# Pulse energy after: 0.04816297294911753 nJ
# Step: 35 Distance remaining: 0.013000000000000001
# Pulse energy after: 0.04817916194046812 nJ
# Step: 36 Distance remaining: 0.0128
# Pulse energy after: 0.04819613352437543 nJ
# Step: 37 Distance remaining: 0.0126
# Pulse energy after: 0.04819033198503508 nJ
# Step: 38 Distance remaining: 0.0124
# Pulse energy after: 0.04814645853802167 nJ
# Step: 39 Distance remaining: 0.0122
# Pulse energy after: 0.048064497300435244 nJ
# Step: 40 Distance remaining: 0.012
# Pulse energy after: 0.04796222472011867 nJ
# Step: 41 Distance remaining: 0.011800000000000001
# Pulse energy after: 0.04787013678706351 nJ
# Step: 42 Distance remaining: 0.011600000000000001
# Pulse energy after: 0.04781655035890791 nJ
# Step: 43 Distance remaining: 0.011400000000000002
# Pulse energy after: 0.04780976278310206 nJ
# Step: 44 Distance remaining: 0.011200000000000002
# Pulse energy after: 0.0478325515456623 nJ
# Step: 45 Distance remaining: 0.011000000000000001
# Pulse energy after: 0.047854375250432485 nJ
# Step: 46 Distance remaining: 0.0108
# Pulse energy after: 0.047850448701776904 nJ
# Step: 47 Distance remaining: 0.0106
# Pulse energy after: 0.047812894173693915 nJ
# Step: 48 Distance remaining: 0.010400000000000001
# Pulse energy after: 0.047749524584179436 nJ
# Step: 49 Distance remaining: 0.0102
# Pulse energy after: 0.04767782808354145 nJ
# Step: 50 Distance remaining: 0.01
# Pulse energy after: 0.047618331271439884 nJ
# Step: 51 Distance remaining: 0.0098
# Pulse energy after: 0.04758521395437055 nJ
# Step: 52 Distance remaining: 0.0096
# Pulse energy after: 0.0475775021264832 nJ
# Step: 53 Distance remaining: 0.0094
# Pulse energy after: 0.047579791440072246 nJ
# Step: 54 Distance remaining: 0.0092
# Pulse energy after: 0.04757286529513271 nJ
# Step: 55 Distance remaining: 0.009
# Pulse energy after: 0.047546627714213724 nJ
# Step: 56 Distance remaining: 0.008799999999999999
# Pulse energy after: 0.047502956192876464 nJ
# Step: 57 Distance remaining: 0.008600000000000002
# Pulse energy after: 0.04745295357931184 nJ
# Step: 58 Distance remaining: 0.008400000000000001
# Pulse energy after: 0.04740632750575078 nJ
# Step: 59 Distance remaining: 0.0082
# Pulse energy after: 0.047368632998931716 nJ
# Step: 60 Distance remaining: 0.008
# Pulse energy after: 0.04734075233694902 nJ
# Step: 61 Distance remaining: 0.0078000000000000005
# Pulse energy after: 0.0473168297954964 nJ
# Step: 62 Distance remaining: 0.0076
# Pulse energy after: 0.04728998381072004 nJ
# Step: 63 Distance remaining: 0.0074
# Pulse energy after: 0.04725567007467703 nJ
# Step: 64 Distance remaining: 0.0072
# Pulse energy after: 0.04721309075507805 nJ
# Step: 65 Distance remaining: 0.006999999999999999
# Pulse energy after: 0.047164552781831 nJ
# Step: 66 Distance remaining: 0.0068
# Pulse energy after: 0.04711467045923477 nJ
# Step: 67 Distance remaining: 0.006599999999999999
# Pulse energy after: 0.047066851053891544 nJ
# Step: 68 Distance remaining: 0.0063999999999999994
# Pulse energy after: 0.047024656508375166 nJ
# Step: 69 Distance remaining: 0.0062000000000000015
# Pulse energy after: 0.04699072293611384 nJ
# Step: 70 Distance remaining: 0.006000000000000001
# Pulse energy after: 0.04696594507791145 nJ
# Step: 71 Distance remaining: 0.0058000000000000005
# Pulse energy after: 0.04694564601532057 nJ
# Step: 72 Distance remaining: 0.005600000000000001
# Pulse energy after: 0.04692449283081048 nJ
# Step: 73 Distance remaining: 0.0054
# Pulse energy after: 0.04689251118586279 nJ
# Step: 74 Distance remaining: 0.005200000000000001
# Pulse energy after: 0.04684625012942096 nJ
# Step: 75 Distance remaining: 0.005
# Pulse energy after: 0.04678838807251788 nJ
# Step: 76 Distance remaining: 0.0048
# Pulse energy after: 0.04672990597088337 nJ
# Step: 77 Distance remaining: 0.0046
# Pulse energy after: 0.04668309369129384 nJ
# Step: 78 Distance remaining: 0.004399999999999999
# Pulse energy after: 0.0466589199547913 nJ
# Step: 79 Distance remaining: 0.0042
# Pulse energy after: 0.046655787296690426 nJ
# Step: 80 Distance remaining: 0.003999999999999999
# Pulse energy after: 0.04665992374772585 nJ
# Step: 81 Distance remaining: 0.003799999999999999
# Pulse energy after: 0.04665264084642185 nJ
# Step: 82 Distance remaining: 0.003600000000000001
# Pulse energy after: 0.046619415117002135 nJ
# Step: 83 Distance remaining: 0.0034000000000000007
# Pulse energy after: 0.046557972161549 nJ
# Step: 84 Distance remaining: 0.0032000000000000006
# Pulse energy after: 0.04648316982977728 nJ
# Step: 85 Distance remaining: 0.0030000000000000005
# Pulse energy after: 0.046418157418902484 nJ
# Step: 86 Distance remaining: 0.0028000000000000004
# Pulse energy after: 0.04638158792856781 nJ
# Step: 87 Distance remaining: 0.0026000000000000003
# Pulse energy after: 0.04637864287970056 nJ
# Step: 88 Distance remaining: 0.0024
# Pulse energy after: 0.04639629051744766 nJ
# Step: 89 Distance remaining: 0.0021999999999999997
# Pulse energy after: 0.046408297477127713 nJ
# Step: 90 Distance remaining: 0.0019999999999999996
# Pulse energy after: 0.04639272800128058 nJ
# Step: 91 Distance remaining: 0.0017999999999999995
# Pulse energy after: 0.04634161262531015 nJ
# Step: 92 Distance remaining: 0.0015999999999999992
# Pulse energy after: 0.046265778931278576 nJ
# Step: 93 Distance remaining: 0.0013999999999999991
# Pulse energy after: 0.046191544960822506 nJ
# Step: 94 Distance remaining: 0.0012000000000000012
# Pulse energy after: 0.0461453997459125 nJ
# Step: 95 Distance remaining: 0.0010000000000000009
# Pulse energy after: 0.04613697426031804 nJ
# Step: 96 Distance remaining: 0.0008000000000000007
# Pulse energy after: 0.04615471678950406 nJ
# Step: 97 Distance remaining: 0.0006000000000000006
# Pulse energy after: 0.0461736713149698 nJ
# Step: 98 Distance remaining: 0.00040000000000000034
# Pulse energy after: 0.04616826049192013 nJ
# Step: 99 Distance remaining: 0.00020000000000000017
# Pulse energy after: 0.04612786027094359 nJ
# Pulse energy after Simple Fiber : 0.04620313626711153 nJ
# C:\Users\PallaviPunj\AppData\Local\Temp\ipykernel_1008\3916353699.py:42: RuntimeWarning: divide by zero encountered in log10
#   return 10 * np.log10(np.abs(num)**2)

# %% [markdown]
# dual pump (50fs - 1064nm and 100fs 532nm) supercontinuum calculation

# %%
########## Parameters:
Pulse1   = .200  # pulse duration (ps)
Pulse2   = .200
Pulse3   = .200 

pulseWL1 = 1035.0         # pulse central wavelength (nm)\
pulseWL2 = pulseWL1/2.0   
pulseWL3 = pulseWL1/0.74  

EPP1    = 0.100e-6  # Pulse energy (J)
EPP2    = 0.100e-6
EPP3    = 0.010e-6  
  
Length  = 10.00 # mm

GDD1     = 0*0.040   # Group delay dispersion (ps^2)
GDD2     = 0*0.040
GDD3     = 0*0.020

TOD      = 0.0        # Third order dispersion (ps^3), currently the same for all pulses

Window  = 6.0   # simulation window (ps)
Steps   = 20 # simulation steps - note that the integrator typically takes many more steps than this 
Points  = 2**16 # simulation points
error   = 0.001  # the error desired for the integration. 0.001 is usually good. larger allows for faster calculations

Alpha   = 0.0   # attentuation coefficient (dB/cm, pretty sure)

Aeff = 2*np.pi*10e-6**2   # effective area in m^2
n2_per_torr = 1.1e-22/760 # nonlinearity in m^2/(W torr)

Gamma_per_torr = 2*np.pi*n2_per_torr/(pulseWL1*1e-9 * Aeff)

Raman = False # enable Raman? (calculates fused silica Raman response)
Steep = True  # enable self-steepening?

fund_THz = 3e8/(pulseWL1*1e-9) * 1e-12
loss_lo = fund_THz * 5.5
loss_hi = fund_THz * 6.5
loss  = 0 # Alpha in the special attentuation region, in dB/cm

max_pressure = 1350 # pressure in mBar
#######################


fibWL = pulseWL1   # Center WL (nm)
alpha = np.log((10**(Alpha * 0.1))) * 100  # convert from dB/cm to 1/m
loss  = np.log((10**(loss  * 0.1))) * 100

def dB(num):
    return 10 * np.log10(np.abs(num)**2)

def pressure_at_z(z):
    # code can be added here to change pressure as a function of position
    return max_pressure

def myDispersion(z):
    # pressure = pressure_at_z(z*1e3/Length)
    pressure = pressure_at_z(z*1e3/Length)
    
    waves = np.linspace(0.05, 1.2, 1000)
    RIs = 0*waves + 1 # just set the index to 1 everywhere
    return waves*1e3, RIs

def myGamma(z):
    pressure = pressure_at_z(z*1e3/Length)
    pressure_torr = pressure*760.0/1000.0
    return pressure_torr * Gamma_per_torr
    


fig = plt.figure(figsize=(8,8))
ax0 = plt.subplot2grid((3,2), (0, 0), rowspan=1)
ax1 = plt.subplot2grid((3,2), (0, 1), rowspan=1)
ax2 = plt.subplot2grid((3,2), (1, 0), rowspan=2, sharex=ax0)
ax3 = plt.subplot2grid((3,2), (1, 1), rowspan=2, sharex=ax1)

axs = (ax0, ax1, ax2, ax3)

fig.suptitle('Pulse 1: %.0f nm, %.0f fs, %.0f nJ \nPulse 2: %.0f nm, %.0f fs, %.0f nJ\nPulse 3: %.0f nm, %.0f fs, %.0f nJ'%(pulseWL1, Pulse1*1e3, EPP1*1e9, pulseWL2, Pulse2*1e3, EPP2*1e9, pulseWL3, Pulse3*1e3, EPP3*1e9))


# set up the pulse parameters
pulse1 = SechPulse(1, Pulse1/1.76, pulseWL1, time_window_ps=Window, NPTS=Points, frep_MHz=100, power_is_avg=False)
pulse2 = SechPulse(1, Pulse2/1.76, pulseWL2, time_window_ps=Window, NPTS=Points, frep_MHz=100, power_is_avg=False)
pulse3 = SechPulse(1, Pulse3/1.76, pulseWL3, time_window_ps=Window, NPTS=Points, frep_MHz=100, power_is_avg=False)

pulse1.set_epp(EPP1)
pulse2.set_epp(EPP2)
pulse3.set_epp(EPP3)

pulse1.chirp_pulse_W(GDD1)
pulse2.chirp_pulse_W(GDD2)
pulse3.chirp_pulse_W(GDD3)

# pulse2.rotate_spectrum_to_new_center_wl(pulseWL2)
pulse1.set_AW(pulse1.AW + pulse2.interpolate_to_new_center_wl(pulseWL1).AW + pulse3.interpolate_to_new_center_wl(pulseWL1).AW)

fiber1 = fiber.FiberInstance()
fiber1.generate_fiber(Length * 1e-3, center_wl_nm=fibWL, betas=(0,0,0),
                              gamma_W_m=0, gain=-alpha)

fiber1.set_dispersion_function(myDispersion, dispersion_format='n')
fiber1.set_gamma_function(myGamma)

F = pulse1.F_THz     # Frequency grid of pulse (THz)

# include loss:
gain = -alpha * np.zeros(F.size)
# gain[((F>loss_lo)&(F<loss_hi))] = -loss
gain[((np.abs(F)>loss_lo)&(np.abs(F)<loss_hi))] = -loss
fiber1.set_gain(gain)

# Propagation
evol = SSFM.SSFM(local_error=error, USE_SIMPLE_RAMAN=True,
                 disable_Raman=np.logical_not(Raman),
                 disable_self_steepening=np.logical_not(Steep))


y, AW, AT, pulse_out = evol.propagate(pulse_in=pulse1, fiber=fiber1, n_steps=Steps, reload_fiber_each_step=True)


########## That's it! Physics complete. Just plotting commands from here! ################


def dB(num):
    return 10 * np.log10(np.abs(num)**2)

zW = dB( np.transpose(AW)[:, (F > 0)] )
zT = dB( np.transpose(AT) )

y_mm = y * 1e3 # convert distance to mm

ax0.plot(pulse_out.F_THz,    dB(pulse_out.AW),  color = 'r')
ax1.plot(pulse_out.T_ps,     dB(pulse_out.AT),  color = 'r')

ax0.plot(pulse1.F_THz,    dB(pulse1.AW),  color = 'b')
ax1.plot(pulse1.T_ps,     dB(pulse1.AT),  color = 'b')

extent = (np.min(F[F > 0]), np.max(F[F > 0]), 0, Length)

ax2.imshow(zW, extent=extent, 
           vmin=np.max(zW) - 200.0, vmax=np.max(zW), 
           aspect='auto', origin='lower')

extent = (np.min(pulse1.T_ps), np.max(pulse1.T_ps), np.min(y_mm), Length)
ax3.imshow(zT, extent=extent, 
           vmin=np.max(zT) - 100.0, vmax=np.max(zT), 
           aspect='auto', origin='lower')

ax0.set_ylabel('Intensity (dB)')
ax0.set_ylim( - 250,  100)
ax1.set_ylim( - 200, 100)

ax2.set_ylabel('Propagation distance (mm)')
ax2.set_xlabel('Frequency (THz)')
ax2.set_xlim(0,4000)

ax3.set_xlabel('Time (ps)')

for ax in axs:
    ax.grid(alpha=0.1)

plt.subplots_adjust(left=0.10, bottom=0.07, right=0.98, top=0.89, wspace=0.26, hspace=0.20)

plt.show()
# Out:
# Pulse energy before Simple Fiber : 209.90792023197537 nJ
# pulse energy in  3392467.3488119524
# copied as   3392467.3488119524
# Step: 0 Distance remaining: 0.01
# Pulse energy after: 209.69270682961684 nJ
# Step: 1 Distance remaining: 0.0095
# Pulse energy after: 209.6927626441234 nJ
# Step: 2 Distance remaining: 0.009000000000000001
# Pulse energy after: 209.69282148741453 nJ
# Step: 3 Distance remaining: 0.0085
# Pulse energy after: 209.6928833506372 nJ
# Step: 4 Distance remaining: 0.008
# Pulse energy after: 209.6929482244421 nJ
# Step: 5 Distance remaining: 0.0075
# Pulse energy after: 209.69301609898957 nJ
# Step: 6 Distance remaining: 0.006999999999999999
# Pulse energy after: 209.69308696395345 nJ
# Step: 7 Distance remaining: 0.006500000000000001
# Pulse energy after: 209.6931608085259 nJ
# Step: 8 Distance remaining: 0.006
# Pulse energy after: 209.69323762142332 nJ
# Step: 9 Distance remaining: 0.0055000000000000005
# Pulse energy after: 209.69331739089066 nJ
# Step: 10 Distance remaining: 0.005
# Pulse energy after: 209.69340010470853 nJ
# Step: 11 Distance remaining: 0.0045
# Pulse energy after: 209.69348575019782 nJ
# Step: 12 Distance remaining: 0.004
# Pulse energy after: 209.69357431422623 nJ
# Step: 13 Distance remaining: 0.0034999999999999996
# Pulse energy after: 209.69366578321458 nJ
# Step: 14 Distance remaining: 0.0030000000000000005
# Pulse energy after: 209.69376014314304 nJ
# Step: 15 Distance remaining: 0.0025
# Pulse energy after: 209.69385737955818 nJ
# Step: 16 Distance remaining: 0.0019999999999999996
# Pulse energy after: 209.69395747757983 nJ
# Step: 17 Distance remaining: 0.0015000000000000002
# Pulse energy after: 209.69406042190795 nJ
# Step: 18 Distance remaining: 0.0009999999999999998
# Pulse energy after: 209.6941661968302 nJ
# Step: 19 Distance remaining: 0.0005000000000000004
# Pulse energy after: 209.69427478622927 nJ
# Pulse energy after Simple Fiber : 209.90792023199006 nJ
# timestep: 9.1552734375e-05

# %% [markdown]
# Coherence modeling - 200fs pulse
