# %%
# importing built-in libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# importing non-linear optics library
import pynlo
from pynlo.interactions.FourWaveMixing import SSFM
from pynlo.media.fibers import fiber
from pynlo.light.DerivedPulses import SechPulse

# %%
# setting up parameters

FWHM    = 0.20  # pulse duration (ps)
pulseWL = 1562.6   # pulse central wavelength (nm)
EPP     = 2e-10 # Energy per pulse (J)
GDD     = 0.0    # Group delay dispersion (ps^2)
TOD     = 0.0    # Third order dispersion (ps^3)

Window  = 10.0   # simulation window (ps)
Steps   = 100    # simulation steps
Points  = 2**13  # simulation points

beta2   = -120     # (ps^2/km)
beta3   = 0.00     # (ps^3/km)
beta4   = 0.005    # (ps^4/km)

Length  = 21.05    # length in mm
# thickness = 750  # thikness in nm
# width = 2100     # width in nm

Alpha   = -2.0     # attentuation coefficient (dB/cm)
Gamma   = 1000    # Gamma (1/(W km)

fibWL   = pulseWL # Center WL of fiber (nm)

Raman   = True    # Enable Raman effect?
Steep   = True    # Enable self steepening?

alpha = np.log((10**(Alpha * 0.1))) * 100  # convert from dB/cm to 1/m

# %% [markdown]
# ## Plotting 200fs pulse through fiber

# %%
# set up plots for the results:

fig = plt.figure(figsize=(8,8))
ax0 = plt.subplot2grid((3,2), (0, 0), rowspan=1)
ax1 = plt.subplot2grid((3,2), (0, 1), rowspan=1)
ax2 = plt.subplot2grid((3,2), (1, 0), rowspan=2, sharex=ax0)
ax3 = plt.subplot2grid((3,2), (1, 1), rowspan=2, sharex=ax1)


######## This is where the PyNLO magic happens! ############################

# create the pulse!
pulse = pynlo.light.DerivedPulses.SechPulse(power = 1, # Power will be scaled by set_epp
                                            T0_ps                   = FWHM/1.76,
                                            center_wavelength_nm    = pulseWL,
                                            time_window_ps          = Window,
                                            GDD=GDD, TOD=TOD,
                                            NPTS            = Points,
                                            frep_MHz        = 100,
                                            power_is_avg    = False)
# set the pulse energy!
pulse.set_epp(EPP)

# create the fiber!
fiber1 = pynlo.media.fibers.fiber.FiberInstance()
fiber1.generate_fiber(Length * 1e-3, center_wl_nm=fibWL, betas=(beta2, beta3, beta4),
                              gamma_W_m=Gamma * 1e-3, gvd_units='ps^n/km', gain=-alpha)

# Propagation
evol = pynlo.interactions.FourWaveMixing.SSFM.SSFM(local_error=0.005, USE_SIMPLE_RAMAN=True,
                 disable_Raman              = np.logical_not(Raman),
                 disable_self_steepening    = np.logical_not(Steep))

y, AW, AT, pulse_out = evol.propagate(pulse_in=pulse, fiber=fiber1, n_steps=Steps)

########## That's it! Physics complete. Just plotting commands from here! ################


F = pulse.F_THz     # Frequency grid of pulse (THz)

def dB(num):
    return 10 * np.log10(np.abs(num)**2)

zW = dB( np.transpose(AW)[:, (F > 0)] )
zT = dB( np.transpose(AT) )

y_mm = y * 1e3 # convert distance to mm

ax0.plot(pulse_out.F_THz,    dB(pulse_out.AW),  color = 'r')
ax1.plot(pulse_out.T_ps,     dB(pulse_out.AT),  color = 'r')

ax0.plot(pulse.F_THz,    dB(pulse.AW),  color = 'b')
ax1.plot(pulse.T_ps,     dB(pulse.AT),  color = 'b')

extent = (np.min(F[F > 0]), np.max(F[F > 0]), 0, Length)
ax2.imshow(zW, extent=extent,
           vmin=np.max(zW) - 40.0, vmax=np.max(zW),
           aspect='auto', origin='lower')

extent = (np.min(pulse.T_ps), np.max(pulse.T_ps), np.min(y_mm), Length)
ax3.imshow(zT, extent=extent,
           vmin=np.max(zT) - 40.0, vmax=np.max(zT),
           aspect='auto', origin='lower')


ax0.set_ylabel('Intensity (dB)')
ax0.set_ylim( - 80,  0)
ax1.set_ylim( - 40, 40)

ax2.set_ylabel('Propagation distance (mm)')
ax2.set_xlabel('Frequency (THz)')
ax2.set_xlim(0,400)

ax3.set_xlabel('Time (ps)')

plt.show()
# Out:
# Pulse energy before Simple Fiber : 0.2000000000000001 nJ
# pulse energy in  8675.579228019798
# copied as   8675.579228019798
# Step: 0 Distance remaining: 0.021050000000000003
# Pulse energy after: 0.20086137624894881 nJ
# Step: 1 Distance remaining: 0.020839500000000004
# Pulse energy after: 0.2028149648153679 nJ
# Step: 2 Distance remaining: 0.020629
# Pulse energy after: 0.20478675432013985 nJ
# Step: 3 Distance remaining: 0.020418500000000003
# Pulse energy after: 0.20677688512709116 nJ
# Step: 4 Distance remaining: 0.020208
# Pulse energy after: 0.2087854920392969 nJ
# Step: 5 Distance remaining: 0.0199975
# Pulse energy after: 0.21081270364546062 nJ
# Step: 6 Distance remaining: 0.019787000000000003
# Pulse energy after: 0.2128586415921348 nJ
# Step: 7 Distance remaining: 0.0195765
# Pulse energy after: 0.21492341981274354 nJ
# Step: 8 Distance remaining: 0.019366000000000005
# Pulse energy after: 0.2170071438242751 nJ
# Step: 9 Distance remaining: 0.019155500000000002
# Pulse energy after: 0.21910990928664367 nJ
# Step: 10 Distance remaining: 0.018945000000000004
# Pulse energy after: 0.22123180179249502 nJ
# Step: 11 Distance remaining: 0.0187345
# Pulse energy after: 0.22337289618587283 nJ
# Step: 12 Distance remaining: 0.018524000000000002
# Pulse energy after: 0.22553325656888026 nJ
# Step: 13 Distance remaining: 0.018313500000000003
# Pulse energy after: 0.2277129372587594 nJ
# Step: 14 Distance remaining: 0.018103
# Pulse energy after: 0.22991198539400814 nJ
# Step: 15 Distance remaining: 0.017892500000000002
# Pulse energy after: 0.23213044630621887 nJ
# Step: 16 Distance remaining: 0.017682000000000003
# Pulse energy after: 0.23436837342252023 nJ
# Step: 17 Distance remaining: 0.0174715
# Pulse energy after: 0.23662584544849619 nJ
# Step: 18 Distance remaining: 0.017261000000000002
# Pulse energy after: 0.23890299502841067 nJ
# Step: 19 Distance remaining: 0.017050500000000003
# Pulse energy after: 0.24120005507975306 nJ
# Step: 20 Distance remaining: 0.016840000000000004
# Pulse energy after: 0.2435174314442689 nJ
# Step: 21 Distance remaining: 0.016629500000000002
# Pulse energy after: 0.24585581264237022 nJ
# Step: 22 Distance remaining: 0.016419000000000003
# Pulse energy after: 0.24821632695049722 nJ
# Step: 23 Distance remaining: 0.016208500000000004
# Pulse energy after: 0.25060074750862354 nJ
# Step: 24 Distance remaining: 0.015998000000000002
# Pulse energy after: 0.2530117138420512 nJ
# Step: 25 Distance remaining: 0.015787500000000003
# Pulse energy after: 0.2554528569172254 nJ
# Step: 26 Distance remaining: 0.015577000000000002
# Pulse energy after: 0.2579285476403564 nJ
# Step: 27 Distance remaining: 0.015366500000000002
# Pulse energy after: 0.26044271880759323 nJ
# Step: 28 Distance remaining: 0.015156000000000001
# Pulse energy after: 0.26299595718602126 nJ
# Step: 29 Distance remaining: 0.0149455
# Pulse energy after: 0.2655803675309986 nJ
# Pulse energy after: 0.37686743161363623 nJ
# Step: 67 Distance remaining: 0.0069465
# Pulse energy after: 0.3807092961619776 nJ
# Step: 68 Distance remaining: 0.006736
# Pulse energy after: 0.38362965866121485 nJ
# Step: 69 Distance remaining: 0.006525500000000002
# Pulse energy after: 0.38545896640676797 nJ
# Step: 70 Distance remaining: 0.006315000000000002
# Pulse energy after: 0.38738199887494495 nJ
# Step: 71 Distance remaining: 0.006104500000000001
# Pulse energy after: 0.39091652458243875 nJ
# Step: 72 Distance remaining: 0.005894000000000002
# Pulse energy after: 0.3958977362954701 nJ
# Step: 73 Distance remaining: 0.005683500000000001
# Pulse energy after: 0.4014448235411153 nJ
# Step: 74 Distance remaining: 0.005473000000000001
# Pulse energy after: 0.40653161853883757 nJ
# Step: 75 Distance remaining: 0.005262500000000001
# Pulse energy after: 0.4107610126168862 nJ
# Step: 76 Distance remaining: 0.005052
# Pulse energy after: 0.41475897186676874 nJ
# Step: 77 Distance remaining: 0.0048415
# Pulse energy after: 0.4186840491103656 nJ
# Step: 78 Distance remaining: 0.004631
# Pulse energy after: 0.4225526397824911 nJ
# Step: 79 Distance remaining: 0.0044205
# Pulse energy after: 0.4266074422507044 nJ
# Step: 80 Distance remaining: 0.004209999999999999
# Pulse energy after: 0.43074014908670194 nJ
# Step: 81 Distance remaining: 0.0039995
# Pulse energy after: 0.43478945687980325 nJ
# Step: 82 Distance remaining: 0.0037890000000000016
# Pulse energy after: 0.43861127382167236 nJ
# Step: 83 Distance remaining: 0.0035785000000000014
# Pulse energy after: 0.4421540588527819 nJ
# Step: 84 Distance remaining: 0.003368000000000001
# Pulse energy after: 0.4455776364491446 nJ
# Step: 85 Distance remaining: 0.003157500000000001
# Pulse energy after: 0.44926271917615435 nJ
# Step: 86 Distance remaining: 0.002947000000000001
# Pulse energy after: 0.45374999306567326 nJ
# Step: 87 Distance remaining: 0.0027365000000000007
# Pulse energy after: 0.4589468868948489 nJ
# Step: 88 Distance remaining: 0.002526
# Pulse energy after: 0.4642289337693353 nJ
# Step: 89 Distance remaining: 0.0023155
# Pulse energy after: 0.46913647049896906 nJ
# Step: 90 Distance remaining: 0.0021049999999999997
# Pulse energy after: 0.4736863741316254 nJ
# Step: 91 Distance remaining: 0.0018944999999999997
# Pulse energy after: 0.4780457595044218 nJ
# Step: 92 Distance remaining: 0.0016839999999999993
# Pulse energy after: 0.4824144964131136 nJ
# Step: 93 Distance remaining: 0.0014734999999999991
# Pulse energy after: 0.48691271860109336 nJ
# Step: 94 Distance remaining: 0.0012630000000000013
# Pulse energy after: 0.4914763964864817 nJ
# Step: 95 Distance remaining: 0.0010525000000000011
# Pulse energy after: 0.4959649399839463 nJ
# Step: 96 Distance remaining: 0.0008420000000000008
# Pulse energy after: 0.5003968681256623 nJ
# Step: 97 Distance remaining: 0.0006315000000000007
# Pulse energy after: 0.5049593661077053 nJ
# Step: 98 Distance remaining: 0.0004210000000000004
# Pulse energy after: 0.5097920104269112 nJ
# Step: 99 Distance remaining: 0.0002105000000000002
# Pulse energy after: 0.514819922107757 nJ
# Pulse energy after Simple Fiber : 0.5152558844352825 nJ
# C:\Users\PallaviPunj\AppData\Local\Temp\ipykernel_5956\3916353699.py:42: RuntimeWarning: divide by zero encountered in log10
#   return 10 * np.log10(np.abs(num)**2)
